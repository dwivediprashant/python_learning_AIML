# %%
import pandas as pd

# %%
data=pd.read_csv("./data/StudentPerformanceFactors.csv")
data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
data.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
data.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
# selecting column 
data[["Attendance","Exam_Score"]].sample(7)
# Out:
#       Attendance  Exam_Score
# 66            86          69
# 4479          87          71
# 908           98          69
# 2367          90          67
# 1369          83          70
# 6278          86          66
# 5096          81          68

# %%
# using copy() fxn : so that original data remain consistent
Family_Income=data["Family_Income"].copy() 
Family_Income[0]="modified" 
Family_Income.head(10)
# Out:
# 0    modified
# 1      Medium
# 2      Medium
# 3      Medium
# 4      Medium
# 5      Medium
# 6         Low
# 7        High
# 8      Medium
# 9        High
# Name: Family_Income, dtype: object

# %%
data["Family_Income"].head(10)
# Out:
# 0       Low
# 1    Medium
# 2    Medium
# 3    Medium
# 4    Medium
# 5    Medium
# 6       Low
# 7      High
# 8    Medium
# 9      High
# Name: Family_Income, dtype: object

# %%
data.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
# selecting rows : loc and iloc
data.loc[0]
# Out:
# Hours_Studied                          23
# Attendance                             84
# Parental_Involvement                  Low
# Access_to_Resources                  High
# Extracurricular_Activities             No
# Sleep_Hours                             7
# Previous_Scores                        73
# Motivation_Level                      Low
# Internet_Access                       Yes
# Tutoring_Sessions                       0
# Family_Income                         Low
# Teacher_Quality                    Medium
# School_Type                        Public
# Peer_Influence                   Positive
# Physical_Activity                       3
# Learning_Disabilities                  No
# Parental_Education_Level      High School
# Distance_from_Home                   Near
# Gender                               Male
# Exam_Score                             67
# Name: 0, dtype: object

# %%
data.loc[0:3]
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# ...

# %%
data.iloc[0]
# Out:
# Hours_Studied                          23
# Attendance                             84
# Parental_Involvement                  Low
# Access_to_Resources                  High
# Extracurricular_Activities             No
# Sleep_Hours                             7
# Previous_Scores                        73
# Motivation_Level                      Low
# Internet_Access                       Yes
# Tutoring_Sessions                       0
# Family_Income                         Low
# Teacher_Quality                    Medium
# School_Type                        Public
# Peer_Influence                   Positive
# Physical_Activity                       3
# Learning_Disabilities                  No
# Parental_Education_Level      High School
# Distance_from_Home                   Near
# Gender                               Male
# Exam_Score                             67
# Name: 0, dtype: object

# %%
data.iloc[0:3]
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# ...

# %%
# slecting col and row both at a time : iloc and loc
data.loc[0:2,"Attendance"]
# Out:
# 0    84
# 1    64
# 2    98
# Name: Attendance, dtype: int64

# %%
data.loc[0:3,["Attendance","Hours_Studied","Sleep_Hours"]]
# Out:
#    Attendance  Hours_Studied  Sleep_Hours
# 0          84             23            7
# 1          64             19            8
# 2          98             24            7
# 3          89             29            8

# %%
data.iloc[0:3,["Attendance","Hours_Studied","Sleep_Hours"]] # will throw error because iloc expect numeric index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data.iloc[0:3,["Attendance","Hours_Studied","Sleep_Hours"]] # will throw error because iloc expect numeric index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1691, in _iLocIndexer._getitem_tuple(self, tup)
#    1690 def _getitem_tuple(self, tup: tuple):
# -> 1691     tup = self._validate_tuple_indexer(tup)
#    1692     with suppress(IndexingError):
#    1693         return self._getitem_lowerdim(tup)
# ...

# %%
data.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
data.iloc[0:3,[1,0,5]]
# Out:
#    Attendance  Hours_Studied  Sleep_Hours
# 0          84             23            7
# 1          64             19            8
# 2          98             24            7

# %%
data.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
# Filtering of data based on conditions

# print attendance = 100
data[ data["Attendance"] ==100]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 74                4         100                 High                High
# 106              31         100               Medium              Medium
# 222              24         100                 High                High
# 230              16         100                 High                 Low
# 413              28         100                 High                 Low
# ...             ...         ...                  ...                 ...
# 6359             11         100                 High                High
# 6457             26         100               Medium                High
# 6555             12         100                  Low              Medium
# 6580             18         100               Medium                 Low
# 6592             29         100               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
# multiple conditions
cond1= data["Attendance"]==100
cond2=data["Extracurricular_Activities"] == "Yes"
cond3=data["School_Type"]=="Private"
cond4=data["Previous_Scores"]>=90

data[(cond1) & (cond2) & (cond3) &(cond4)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 2191             23         100                  Low              Medium
# 6592             29         100               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 2191                        Yes            5               93
# 6592                        Yes            8              100
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 2191           Medium             Yes                  4           Low
# 6592              Low             Yes                  0           Low
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 2191          Medium     Private        Neutral                  3
# 6592          Medium     Private        Neutral                  5
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home Gender  \
# ...

# %%
# chaining 
data[data["Attendance"]>95 ][["Attendance","Sleep_Hours","Previous_Scores"]]
# Out:
#       Attendance  Sleep_Hours  Previous_Scores
# 2             98            7               91
# 9             98            8               71
# 11            97            6               87
# 21            99            6               84
# 37            99            9               54
# ...          ...          ...              ...
# 6555         100            7               65
# 6566          96            8               85
# 6580         100            8               66
# 6592         100            8              100
# 6600          98            4               54
#
# [751 rows x 3 columns]

# %%
# using query languages
data.query("Sleep_Hours ==10 & Attendance >=90")
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 269              21          95                  Low                 Low
# 451              26          94                 High              Medium
# 494              29          92               Medium              Medium
# 800              26          96                 High                High
# 820              17          96               Medium              Medium
# ...             ...         ...                  ...                 ...
# 5670             35          91                  Low              Medium
# 5845             17          99               Medium              Medium
# 5876             10          98               Medium                 Low
# 6101             21          90                  Low              Medium
# 6214             15          91               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
data.query("Sleep_Hours ==10 & Attendance >=90")[["Exam_Score","Gender"]]
# Out:
#       Exam_Score  Gender
# 269           67    Male
# 451           73    Male
# 494           71    Male
# 800           72  Female
# 820           70  Female
# ...          ...     ...
# 5670          72    Male
# 5845          70    Male
# 5876          66  Female
# 6101          72    Male
# 6214          65    Male
#
# [72 rows x 2 columns]

# %%
hours=10
data.query("Sleep_Hours == @hours & Attendance >=90")[["Exam_Score","Previous_Scores"]]
# Out:
#       Exam_Score  Previous_Scores
# 269           67               84
# 451           73               54
# 494           71               63
# 800           72               64
# 820           70               93
# ...          ...              ...
# 5670          72               63
# 5845          70               86
# 5876          66               66
# 6101          72               95
# 6214          65               61
#
# [72 rows x 2 columns]

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# - 1. Missing values handling

# %%
data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
## HANDLING MISSING VALUES
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
data[["Teacher_Quality" ,"Parental_Education_Level","Distance_from_Home"]]
# Out:
#      Teacher_Quality Parental_Education_Level Distance_from_Home
# 0             Medium              High School               Near
# 1             Medium                  College           Moderate
# 2             Medium             Postgraduate               Near
# 3             Medium              High School           Moderate
# 4               High                  College               Near
# ...              ...                      ...                ...
# 6602          Medium              High School               Near
# 6603            High              High School               Near
# 6604          Medium             Postgraduate               Near
# 6605          Medium              High School                Far
# 6606          Medium             Postgraduate               Near
#
# [6607 rows x 3 columns]

# %%
data["Teacher_Quality"]
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
#          ...
# 6602    Medium
# 6603      High
# 6604    Medium
# 6605    Medium
# 6606    Medium
# Name: Teacher_Quality, Length: 6607, dtype: object

# %%
## Now I think student's Exam_Score  would be most affecting features for Teacher_Quality

clean_data=data.copy()
clean_data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
# handling Teacher_Quality attribute
# I think Exam_Score could be most affecting feature for tecaher quality
clean_data["Exam_Score"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6607 entries, 0 to 6606
# Series name: Exam_Score
# Non-Null Count  Dtype
# --------------  -----
# 6607 non-null   int64
# dtypes: int64(1)
# memory usage: 51.7 KB

# %%
clean_data["Exam_Score"].describe()
# Out:
# count    6607.000000
# mean       67.235659
# std         3.890456
# min        55.000000
# 25%        65.000000
# 50%        67.000000
# 75%        69.000000
# max       101.000000
# Name: Exam_Score, dtype: float64

# %%
clean_data[["Exam_Score","Teacher_Quality"]]
# Out:
#       Exam_Score Teacher_Quality
# 0             67          Medium
# 1             61          Medium
# 2             74          Medium
# 3             71          Medium
# 4             70            High
# ...          ...             ...
# 6602          68          Medium
# 6603          69            High
# 6604          68          Medium
# 6605          68          Medium
# 6606          64          Medium
#
# [6607 rows x 2 columns]

# %%
clean_data[clean_data["Teacher_Quality"].isnull()==True][["Teacher_Quality","Exam_Score"]]
# Out:
#      Teacher_Quality  Exam_Score
# 127              NaN          69
# 396              NaN          67
# 457              NaN          65
# 570              NaN          66
# 593              NaN          69
# ...              ...         ...
# 6414             NaN          61
# 6427             NaN          68
# 6461             NaN          69
# 6579             NaN          67
# 6596             NaN          66
#
# [78 rows x 2 columns]

# %%
clean_data.loc[clean_data["Teacher_Quality"].isnull() & clean_data["Exam_Score"].between(55,65),"Teacher_Quality"]="Low"

# %%
clean_data.loc[clean_data["Teacher_Quality"].isnull() & clean_data["Exam_Score"].between(66,75),"Teacher_Quality"]="Medium"

# %%
clean_data.loc[clean_data["Teacher_Quality"].isnull() & clean_data["Exam_Score"].between(76,clean_data["Exam_Score"].max()),"Teacher_Quality"]="Low"

# %%
clean_data["Teacher_Quality"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6607 entries, 0 to 6606
# Series name: Teacher_Quality
# Non-Null Count  Dtype
# --------------  -----
# 6607 non-null   object
# dtypes: object(1)
# memory usage: 51.7+ KB

# %%
#-----------xxxx----Teacher_Quality feature has all non null values------------xxxx-------

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6607 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
#Parental_Education_Level feature
clean_data["Parental_Education_Level"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6607 entries, 0 to 6606
# Series name: Parental_Education_Level
# Non-Null Count  Dtype
# --------------  -----
# 6517 non-null   object
# dtypes: object(1)
# memory usage: 51.7+ KB

# %%
clean_data["Parental_Education_Level"].describe()
# Out:
# count            6517
# unique              3
# top       High School
# freq             3223
# Name: Parental_Education_Level, dtype: object

# %%
clean_data["Parental_Education_Level"].unique()
# Out:
# array(['High School', 'College', 'Postgraduate', nan], dtype=object)

# %%
clean_data["Parental_Education_Level"].isnull().sum()
# Out:
# np.int64(90)

# %%
clean_data.sample(7)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 2377             12          74                 High                 Low
# 290              19          60               Medium                High
# 3617             18          95               Medium                High
# 2873             16          78                  Low                High
# 4707             17          62               Medium                 Low
# 4428             21          77                 High              Medium
# 6599             30          94               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 2377                        Yes            8               66
# 290                         Yes            7               72
# 3617                        Yes            6               94
# 2873                         No            9               90
# 4707                         No            8               86
# ...

# %%
clean_data.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
clean_data["Family_Income"].describe()
# Out:
# count     6607
# unique       3
# top        Low
# freq      2672
# Name: Family_Income, dtype: object

# %%
clean_data["Family_Income"].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
# using Family_Income to fill nan val in parent edu level
clean_data.loc[clean_data["Parental_Education_Level"].isnull() & (clean_data["Family_Income"]=="Low"),"Parental_Education_Level"]="High School"

# %%
# using Family_Income to fill nan val in parent edu level
clean_data.loc[clean_data["Parental_Education_Level"].isnull() & (clean_data["Family_Income"]=="Medium"),"Parental_Education_Level"]="College"

# %%
# using Family_Income to fill nan val in parent edu level
clean_data.loc[clean_data["Parental_Education_Level"].isnull() & (clean_data["Family_Income"]=="High"),"Parental_Education_Level"]="Postgraduate"

# %%
clean_data["Parental_Education_Level"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6607 entries, 0 to 6606
# Series name: Parental_Education_Level
# Non-Null Count  Dtype
# --------------  -----
# 6607 non-null   object
# dtypes: object(1)
# memory usage: 51.7+ KB

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6607 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
#------------xxx-------filled missing val for Parental_Education_Level----------xxx-------

# %%
#--Distance_from_Home 
clean_data["Distance_from_Home"].isnull().sum()
# Out:
# np.int64(67)

# %%
clean_data["Distance_from_Home"].describe()
# Out:
# count     6540
# unique       3
# top       Near
# freq      3884
# Name: Distance_from_Home, dtype: object

# %%
clean_data["Distance_from_Home"].unique()
# Out:
# array(['Near', 'Moderate', 'Far', nan], dtype=object)

# %%
clean_data.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
# as there is no strong feature that is affecting Distance_from_Home feat so we r going to use ffill
clean_data["Distance_from_Home"]=clean_data["Distance_from_Home"].ffill()

# %%
clean_data["Distance_from_Home"].isnull().sum()
# Out:
# np.int64(0)

# %%
#-------------xxxxxx--------"Distance_from_Home" doesn't contains null val----xxxxxxx-------------
